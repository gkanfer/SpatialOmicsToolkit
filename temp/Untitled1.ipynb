# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from spatialdata import SpatialData

from napari_spatialdata import Interactive

plt.rcParams["figure.figsize"] = (20, 20)

FILE_PATH = "/data/kanferg/Sptial_Omics/projects/NguyenLab/data/CS037196_Trautmann_Xenium/SCAF4316/PrimaryAnalysisOutput/SCAF4316_PA_xenium/output-XETG00202__0040844_Left__SCAF04316_Left_R1__20241121__163918.zarr" # Change this
sdata = SpatialData.read(FILE_PATH)
# Out:
# /gpfs/gsfs10/users/kanferg/conda/envs/spatialdata_env/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /gpfs/gsfs10/users/kanferg/conda/envs/spatialdata_env/lib/python3.12/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /gpfs/gsfs10/users/kanferg/conda/envs/spatialdata_env/lib/python3.12/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# ...

# %%
interactive = Interactive(sdata)
interactive.run()
# Out:
# WARNING: QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-kanferg'
# 2024-12-01 10:17:35.911 | INFO     | napari_spatialdata._view:_on_layer_update:357 - Updating layer.
# 2024-12-01 10:17:35.913 | INFO     | napari_spatialdata._view:_on_layer_update:357 - Updating layer.
# 2024-12-01 10:17:46.106 | INFO     | napari_spatialdata._view:_on_layer_update:357 - Updating layer.
# 2024-12-01 10:17:46.112 | INFO     | napari_spatialdata._view:_on_layer_update:357 - Updating layer.
# 2024-12-01 10:17:55.524 | INFO     | napari_spatialdata._view:_on_layer_update:357 - Updating layer.
# 2024-12-01 10:17:55.528 | INFO     | napari_spatialdata._view:_on_layer_update:357 - Updating layer.
# 2024-12-01 10:17:55.530 | INFO     | napari_spatialdata._view:_on_layer_update:357 - Updating layer.
# 2024-12-01 10:17:55.957 | INFO     | napari_spatialdata._view:_on_layer_update:357 - Updating layer.
# ...

# %%
sdata
# Out:
# SpatialData object, with associated Zarr store: /gpfs/gsfs10/users/kanferg/Sptial_Omics/projects/NguyenLab/data/CS037196_Trautmann_Xenium/SCAF4316/PrimaryAnalysisOutput/SCAF4316_PA_xenium/output-XETG00202__0040844_Left__SCAF04316_Left_R1__20241121__163918.zarr
# ├── Images
# │     └── 'morphology_focus': DataTree[cyx] (5, 91801, 48336), (5, 45900, 24168), (5, 22950, 12084), (5, 11475, 6042), (5, 5737, 3021)
# ├── Labels
# │     ├── 'cell_labels': DataTree[yx] (91801, 48336), (45900, 24168), (22950, 12084), (11475, 6042), (5737, 3021)
# │     └── 'nucleus_labels': DataTree[yx] (91801, 48336), (45900, 24168), (22950, 12084), (11475, 6042), (5737, 3021)
# ├── Points
# │     └── 'transcripts': DataFrame with shape: (<Delayed>, 13) (3D points)
# ├── Shapes
# │     ├── 'cell_boundaries': GeoDataFrame shape: (310629, 1) (2D shapes)
# │     ├── 'cell_circles': GeoDataFrame shape: (310629, 2) (2D shapes)
# │     ├── 'nucleus_boundaries': GeoDataFrame shape: (288536, 1) (2D shapes)
# ...

# %%
import numpy as np
import pandas as pd
import spatialdata as sd
from geopandas import GeoDataFrame
from shapely import Polygon
from spatialdata.models import ShapesModel
from spatialdata.transformations import Identity
from napari_spatialdata import Interactive
from spatialdata import polygon_query
# Out:
# /gpfs/gsfs10/users/kanferg/conda/envs/spatialdata_env/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(

# %%
path_zarr_correct = "/data/kanferg/Sptial_Omics/projects/NguyenLab/data/CS037196_Trautmann_Xenium/SCAF4316/PrimaryAnalysisOutput/SCAF4316_PA_xenium/output-XETG00202__0040844_Left__SCAF04316_Left_R1__20241121__163918_label_correct.zarr"
sdata = sd.read_zarr(path_zarr_correct)
# Out:
# /gpfs/gsfs10/users/kanferg/conda/envs/spatialdata_env/lib/python3.12/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /gpfs/gsfs10/users/kanferg/conda/envs/spatialdata_env/lib/python3.12/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /gpfs/gsfs10/users/kanferg/conda/envs/spatialdata_env/lib/python3.12/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /gpfs/gsfs10/users/kanferg/conda/envs/spatialdata_env/lib/python3.12/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# ...

# %%
interactive = Interactive(sdata)
interactive.run()
# Out:
# WARNING: QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-kanferg'
# 2024-12-01 14:15:18.126 | INFO     | napari_spatialdata._view:_on_layer_update:357 - Updating layer.
# 2024-12-01 14:15:18.130 | INFO     | napari_spatialdata._view:_on_layer_update:357 - Updating layer.
# 2024-12-01 14:15:38.331 | INFO     | napari_spatialdata._view:_on_layer_update:357 - Updating layer.
# 2024-12-01 14:15:38.339 | INFO     | napari_spatialdata._view:_on_layer_update:357 - Updating layer.
# 2024-12-01 14:16:17.341 | INFO     | napari_spatialdata._view:_on_layer_update:357 - Updating layer.
# 2024-12-01 14:16:17.348 | INFO     | napari_spatialdata._view:_on_layer_update:357 - Updating layer.

# %%
filtered_tables = {}
polygon = sdata.shapes['1'].geometry.iloc[0]
filtered_tables['1'] = polygon_query(sdata, polygon=polygon,target_coordinate_system = 'global')["table"]

# %%
filtered_tables['1']
# Out:
# AnnData object with n_obs × n_vars = 16420 × 5006
#     obs: 'cell_id', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'region', 'z_level', 'cell_labels'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatialdata_attrs'
#     obsm: 'spatial'

# %%
andata_save = filtered_tables['1'].copy()
andata_save.write_h5ad("andata_save.h5ad")

# %%
sdata.shapes['test'].geometry.iloc[0]
# Out:
# <POLYGON ((7821.006 10320.892, 7960.951 10221.765, 8072.906 10330.222, 8092....>

# %%
polygon = sdata.shapes['test'].geometry.iloc[0]

# %%
polygon_query(sdata, polygon=polygon,target_coordinate_system = 'global')["table"]
# Out:
# AnnData object with n_obs × n_vars = 45 × 5006
#     obs: 'cell_id', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'region', 'z_level', 'cell_labels'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatialdata_attrs'
#     obsm: 'spatial'

# %% [markdown]
# # Visualizing Lower-Resolution Morphology Focus Image with Annotations
#
# This section demonstrates how to visualize a lower-resolution version of the `morphology_focus` image from a `SpatialData` object and add text annotations.
#
# ### Step 1: Select the Desired Resolution
# Use the `SpatialData` API to select the appropriate lower-resolution version of the `morphology_focus` image.
#
# ### Step 2: Render the Image and Add Text
# Leverage `matplotlib` to display the image and add text annotations.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from spatialdata import SpatialData
plt.rcParams["figure.figsize"] = (20, 20)

FILE_PATH = "/data/kanferg/Sptial_Omics/projects/NguyenLab/data/CS037196_Trautmann_Xenium/SCAF4316/PrimaryAnalysisOutput/SCAF4316_PA_xenium/output-XETG00202__0040844_Left__SCAF04316_Left_R1__20241121__163918.zarr" # Change this
sdata = SpatialData.read(FILE_PATH)
# Out:
# /gpfs/gsfs10/users/kanferg/conda/envs/spatialdata_env/lib/python3.12/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /gpfs/gsfs10/users/kanferg/conda/envs/spatialdata_env/lib/python3.12/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /gpfs/gsfs10/users/kanferg/conda/envs/spatialdata_env/lib/python3.12/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /gpfs/gsfs10/users/kanferg/conda/envs/spatialdata_env/lib/python3.12/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# ...

# %%
sdata
# Out:
# SpatialData object, with associated Zarr store: /gpfs/gsfs10/users/kanferg/Sptial_Omics/projects/NguyenLab/data/CS037196_Trautmann_Xenium/SCAF4316/PrimaryAnalysisOutput/SCAF4316_PA_xenium/output-XETG00202__0040844_Left__SCAF04316_Left_R1__20241121__163918.zarr
# ├── Images
# │     └── 'morphology_focus': DataTree[cyx] (5, 91801, 48336), (5, 45900, 24168), (5, 22950, 12084), (5, 11475, 6042), (5, 5737, 3021)
# ├── Labels
# │     ├── 'cell_labels': DataTree[yx] (91801, 48336), (45900, 24168), (22950, 12084), (11475, 6042), (5737, 3021)
# │     └── 'nucleus_labels': DataTree[yx] (91801, 48336), (45900, 24168), (22950, 12084), (11475, 6042), (5737, 3021)
# ├── Points
# │     └── 'transcripts': DataFrame with shape: (<Delayed>, 13) (3D points)
# ├── Shapes
# │     ├── 'cell_boundaries': GeoDataFrame shape: (310629, 1) (2D shapes)
# │     ├── 'cell_circles': GeoDataFrame shape: (310629, 2) (2D shapes)
# │     └── 'nucleus_boundaries': GeoDataFrame shape: (288536, 1) (2D shapes)
# ...

# %%
sdata["morphology_focus"].scale3
# Out:
# <xarray.DataTree 'scale3'>
# Group: /scale3
#     Dimensions:  (c: 5, y: 11475, x: 6042)
#     Coordinates:
#       * c        (c) <U22 440B 'DAPI' 'ATP1A1/CD45/E-Cadherin' ... 'dummy'
#       * y        (y) float64 92kB 4.0 12.0 20.0 ... 9.178e+04 9.179e+04 9.18e+04
#       * x        (x) float64 48kB 4.0 12.0 20.0 ... 4.832e+04 4.832e+04 4.833e+04
#     Data variables:
#         image    (c, y, x) uint16 693MB dask.array<chunksize=(1, 4096, 4096), meta=np.ndarray>
